# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Path Loss Dataset 1:
#Rural Dataframe:
DS1_Rural_df = pd.read_csv('/content/drive/MyDrive/Rural.csv')
DS1_Rural_df.head(10)
# Out:
#          Timestamp   Latitude  Longitude    Altitude  ID  near  NLOS  bIdx  \
# 0  7/11/2018 12:55  47.009568   7.380880  659.200000   1     1     1     2
# 1  7/11/2018 12:55  47.009568   7.380880  659.200000   1     1     1     1
# 2  7/11/2018 12:55  47.009568   7.380880  659.200000   1     1     1     1
# 3  7/11/2018 12:55  47.009568   7.380880  659.200000   1     1     1     2
# 4  7/11/2018 12:55  47.009568   7.380880  659.200000   1     1     1     1
# 5  7/11/2018 12:55  47.009568   7.380880  659.200000   1     1     1     2
# 6  7/11/2018 12:55  47.009568   7.380880  659.200000   1     1     1     2
# 7  7/11/2018 12:55  47.009567   7.380880  659.236891   1     1     1     1
# 8  7/11/2018 12:55  47.009564   7.380880  659.346323   1     1     1     2
# 9  7/11/2018 12:55  47.009560   7.380882  659.506175   1     1     1     2
#
#     bAzi  bEle  ...  BID44  BID45  BID46  BID47  BID48  Transmitted Power  \
# 0 -48.75    10  ...    -85    -85    -88    -89    -92              61.93
# 1 -56.25    10  ...    -86    -88    -88    -90    -93              61.93
# 2 -56.25    10  ...    -86    -88    -90    -91    -91              61.93
# 3 -48.75    10  ...    -86    -87    -90    -92    -93              61.93
# 4 -56.25    10  ...    -88    -89    -92    -94    -94              61.93
# 5 -48.75    10  ...    -88    -88    -90    -91    -94              61.93
# 6 -48.75    10  ...    -86    -87    -91    -92    -91              61.93
# 7 -56.25    10  ...    -87    -88    -94    -92    -94              61.93
# 8 -48.75    10  ...    -84    -87    -89    -91    -92              61.93
# 9 -48.75    10  ...    -82    -84    -88    -92    -89              61.93
#
#    TX Latitude  TX Longitude  Distance (km)  Path Loss
# 0     47.00976       7.38095       1.299024     140.93
# 1     47.00976       7.38095       1.299024     140.93
# 2     47.00976       7.38095       1.299024     143.93
# 3     47.00976       7.38095       1.299024     141.93
# 4     47.00976       7.38095       1.299024     142.93
# 5     47.00976       7.38095       1.299024     141.93
# 6     47.00976       7.38095       1.299024     141.93
# 7     47.00976       7.38095       1.306753     143.93
# 8     47.00976       7.38095       1.326083     140.93
# 9     47.00976       7.38095       1.346366     140.93
#
# [10 rows x 65 columns]

# %%
DS1_Rural_df = DS1_Rural_df[['Altitude', 'Distance (km)', 'near', 'bAzi', 'bEle', 'RSRP', 'SINR', 'Transmitted Power', 'Path Loss']]

# %%
DS1_Rural_df.head(10)
# Out:
#      Altitude  Distance (km)  near   bAzi  bEle  RSRP       SINR  \
# 0  659.200000       1.299024     1 -48.75    10   -79  33.178423
# 1  659.200000       1.299024     1 -56.25    10   -79  32.356748
# 2  659.200000       1.299024     1 -56.25    10   -82  33.126863
# 3  659.200000       1.299024     1 -48.75    10   -80  33.326711
# 4  659.200000       1.299024     1 -56.25    10   -81  33.492471
# 5  659.200000       1.299024     1 -48.75    10   -80  33.790338
# 6  659.200000       1.299024     1 -48.75    10   -80  33.368683
# 7  659.236891       1.306753     1 -56.25    10   -82  33.607390
# 8  659.346323       1.326083     1 -48.75    10   -79  34.485073
# 9  659.506175       1.346366     1 -48.75    10   -79  34.170766
#
#    Transmitted Power  Path Loss
# 0              61.93     140.93
# 1              61.93     140.93
# 2              61.93     143.93
# 3              61.93     141.93
# 4              61.93     142.93
# 5              61.93     141.93
# 6              61.93     141.93
# 7              61.93     143.93
# 8              61.93     140.93
# 9              61.93     140.93

# %%
#Suburban Dataframe:
DS1_Suburban_df = pd.read_csv('/content/drive/MyDrive/Suburban.csv')
DS1_Suburban_df.head(10)
# Out:
#          Timestamp   Latitude  Longitude    Altitude  ID  near  NLOS  bIdx  \
# 0  4/24/2018 12:06  46.974884   7.477236  532.026226  12     0     0    28
# 1  4/24/2018 12:06  46.974879   7.477139  531.716000  12     0     0    28
# 2  4/24/2018 12:06  46.974903   7.477028  531.402458  12     0     0    28
# 3  4/24/2018 12:06  46.975940   7.475231  529.975834  12     0     0    25
# 4  4/24/2018 12:07  46.978176   7.471495  536.919685  13     0     1     1
# 5  4/24/2018 12:07  46.978153   7.471496  536.772957  13     0     1    17
# 6  4/24/2018 12:07  46.978131   7.471502  536.550838  13     0     1    17
# 7  4/24/2018 12:08  46.978108   7.471524  536.235690  13     0     1    17
# 8  4/24/2018 12:08  46.978086   7.471556  535.942417  13     0     1    17
# 9  4/24/2018 12:08  46.978064   7.471598  535.351240  13     0     1    17
#
#     bAzi  bEle  ...  BID44  BID45  BID46  BID47  BID48 Transmitted Power  \
# 0  26.25     0  ...  #NUM!  #NUM!  #NUM!  #NUM!  #NUM!             55.84
# 1  26.25     0  ...  #NUM!  #NUM!  #NUM!  #NUM!  #NUM!             55.84
# 2  26.25     0  ...  #NUM!  #NUM!  #NUM!  #NUM!  #NUM!             55.84
# 3   3.75     0  ...  #NUM!  #NUM!  #NUM!  #NUM!  #NUM!             55.84
# 4 -56.25    10  ...   -139   -139  #NUM!  #NUM!   -138             55.84
# 5 -56.25     0  ...  #NUM!  #NUM!  #NUM!  #NUM!   -138             55.84
# 6 -56.25     0  ...  #NUM!  #NUM!  #NUM!  #NUM!   -135             55.84
# 7 -56.25     0  ...  #NUM!  #NUM!  #NUM!   -139   -138             55.84
# 8 -56.25     0  ...  #NUM!  #NUM!  #NUM!   -139   -137             55.84
# 9 -56.25     0  ...  #NUM!  #NUM!  #NUM!   -139   -139             55.84
#
#   TX Latitude TX Longtitude Distance (km) Path Loss
# 0   46.974928      7.472045     32.705610    193.84
# 1   46.974928      7.472045     32.096048    193.84
# 2   46.974928      7.472045     31.394121    185.84
# 3   46.974928      7.472045     21.087319    192.84
# 4   46.974928      7.472045     20.978624    179.84
# 5   46.974928      7.472045     20.838220    178.84
# 6   46.974928      7.472045     20.689082    179.84
# 7   46.974928      7.472045     20.525857    179.84
# 8   46.974928      7.472045     20.352475    178.84
# 9   46.974928      7.472045     20.175956    178.84
#
# [10 rows x 65 columns]

# %%
DS1_Suburban_df = DS1_Suburban_df[['Altitude', 'Distance (km)', 'near', 'bAzi', 'bEle', 'RSRP', 'SINR', 'Transmitted Power', 'Path Loss']]

# %%
#Urban Dataframe:
DS1_Urban_df = pd.read_csv('/content/drive/MyDrive/Urban.csv')
DS1_Urban_df.head(10)
# Out:
#          Timestamp   Latitude  Longitude    Altitude  ID  near  NLOS  bIdx  \
# 0  8/13/2018 13:50  47.369222   8.533266  410.260271   2     1     1    46
# 1  8/13/2018 13:50  47.369223   8.533274  410.540743   2     1     1    48
# 2  8/13/2018 13:50  47.369220   8.533280  410.767534   2     1     1    48
# 3  8/13/2018 13:50  47.369219   8.533280  410.921738   2     1     1    46
# 4  8/13/2018 13:50  47.369218   8.533280  411.107364   2     1     1    46
# 5  8/13/2018 13:50  47.369216   8.533280  411.330251   2     1     1    46
# 6  8/13/2018 13:50  47.369212   8.533277  411.494267   2     1     1    48
# 7  8/13/2018 13:50  47.369210   8.533274  411.500000   2     1     1    48
# 8  8/13/2018 13:50  47.369206   8.533270  411.522315   2     1     1    16
# 9  8/13/2018 13:50  47.369203   8.533266  411.613267   2     1     1    46
#
#     bAzi  bEle  ...  BID44  BID45  BID46  BID47  BID48  Transmitted power  \
# 0  41.25   -10  ...    -99    -91    -87    -94    -93              55.84
# 1  56.25   -10  ...   -106    -93    -94    -94    -90              55.84
# 2  56.25   -10  ...   -103    -92    -94    -95    -91              55.84
# 3  41.25   -10  ...   -102    -91    -90    -94    -93              55.84
# 4  41.25   -10  ...   -102    -91    -90    -94    -93              55.84
# 5  41.25   -10  ...   -102    -91    -89    -95    -93              55.84
# 6  56.25   -10  ...   -102    -94    -93    -93    -87              55.84
# 7  56.25   -10  ...   -104    -93    -93    -91    -89              55.84
# 8  56.25    10  ...   -102    -92    -91    -93    -90              55.84
# 9  41.25   -10  ...   -102    -91    -90    -94    -93              55.84
#
#    TX Latitude  TX Longitude  Distance (km)  Path Loss
# 0     47.36913       8.53276       3.180521     142.84
# 1     47.36913       8.53276       3.234303     145.84
# 2     47.36913       8.53276       3.263841     146.84
# 3     47.36913       8.53276       3.263308     145.84
# 4     47.36913       8.53276       3.262066     145.84
# 5     47.36913       8.53276       3.259942     144.84
# 6     47.36913       8.53276       3.239226     142.84
# 7     47.36913       8.53276       3.214846     144.84
# 8     47.36913       8.53276       3.186895     145.84
# 9     47.36913       8.53276       3.164069     145.84
#
# [10 rows x 65 columns]

# %%
DS1_Urban_df = DS1_Urban_df[['Altitude', 'Distance (km)', 'near', 'bAzi', 'bEle', 'RSRP', 'SINR', 'Transmitted power', 'Path Loss']]

# %%
#Path Loss Dataset 2:
#Baseball Park (Low Density) Dataframe:
DS2_Baseball_df = pd.read_csv('/content/drive/MyDrive/Baseball Park.csv')
DS2_Baseball_PL = pd.read_csv('/content/drive/MyDrive/Baseball Path Loss.csv')
DS2_Baseball_df.head(10)
# Out:
#   TIME_STAMP        Lon       Lat   GPS Lon   GPS Lat  GPS Speed (km/h)  \
# 0    06:35.4 -87.620918  41.87294       NaN       NaN               NaN
# 1    06:35.6 -87.620918  41.87294       NaN       NaN               NaN
# 2    06:36.2 -87.620918  41.87294       NaN       NaN               NaN
# 3    06:36.3 -87.620918  41.87294 -87.62092  41.87294               0.0
# 4    06:36.4 -87.620918  41.87294       NaN       NaN               NaN
# 5    06:36.4 -87.620918  41.87294       NaN       NaN               NaN
# 6    06:37.3 -87.620918  41.87294 -87.62092  41.87294               0.0
# 7    06:37.3 -87.620918  41.87294       NaN       NaN               NaN
# 8    06:37.3 -87.620918  41.87294       NaN       NaN               NaN
# 9    06:37.4 -87.620918  41.87294       NaN       NaN               NaN
#
#    LTE KPI PCell Serving PCI LTE KPI PCell Serving Band  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                       69.0                    Band 66
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# 5                        NaN                        NaN
# 6                        NaN                        NaN
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                       69.0                    Band 66
#
#    LTE KPI PCell Serving EARFCN(DL)  LTE KPI PCell Serving RSRP[dBm]  ...  \
# 0                               NaN                              NaN  ...
# 1                               NaN                              NaN  ...
# 2                           66536.0                           -76.25  ...
# 3                               NaN                              NaN  ...
# 4                               NaN                              NaN  ...
# 5                               NaN                              NaN  ...
# 6                               NaN                              NaN  ...
# 7                               NaN                              NaN  ...
# 8                               NaN                              NaN  ...
# 9                           66536.0                           -77.31  ...
#
#    PCI Beam Switch Analysis PCell Inter-Beam Switch  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
#
#    UE Beam Switch Analysis PCell UE Beam Switch without Tx Beam Switch  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    UE Beam Switch Analysis PCell UE Beam Switch Delay Time [sec]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    API GPS Info Estimated accuracy  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                         3.790092
# 4                              NaN
# 5                              NaN
# 6                         3.790092
# 7                              NaN
# 8                              NaN
# 9                              NaN
#
#   Smart Phone Android System Info Phone Model  \
# 0                                   SM-G998U1
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#    Smart Phone Android System Info Operator  \
# 0                                  Verizon
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                  Verizon
# 5                                  Verizon
# 6                                       NaN
# 7                                  Verizon
# 8                                  Verizon
# 9                                       NaN
#
#    Smart Phone Android System Info Phone OS Ver  \
# 0                                          11.0
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
#
#    Smart Phone Android System Info Battery Temperature  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               42.5
# 5                                                NaN
# 6                                                NaN
# 7                                               42.5
# 8                                                NaN
# 9                                                NaN
#
#   5G-NR RRC NSA RRC State Info NSA RRC State 5G KPI PCell RF Pathloss [dB]
# 0                                        NaN                           NaN
# 1                               LTE RRC Idle                           NaN
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# 5                                        NaN                           NaN
# 6                                        NaN                           NaN
# 7                                        NaN                           NaN
# 8                                        NaN                           NaN
# 9                                        NaN                           NaN
#
# [10 rows x 78 columns]

# %%
DS2_Baseball_df['5G KPI PCell RF Pathloss [dB]'] = DS2_Baseball_PL['5G KPI PCell RF Pathloss [dB]'] #path loss wasn't showing up properly without this step

# %%
DS2_Baseball_df = DS2_Baseball_df[DS2_Baseball_df['5G KPI PCell RF Pathloss [dB]'].notna()]

DS2_Baseball_df = DS2_Baseball_df[['5G KPI PCell RF Serving SS-SINR [dB]', 'LTE KPI PCell Serving RSRP[dBm]', 'LTE KPI PCell Serving RSRQ[dB]', '5G KPI PCell RF Serving SS-RSRQ [dB]', '5G KPI PCell RF Best Beam SS-RSRP [dBm]', '5G KPI PCell RF Pathloss [dB]']]
DS2_Baseball_df = DS2_Baseball_df.ffill()
DS2_Baseball_df = DS2_Baseball_df.dropna()

# %%
#City-Wide(Medium Density) Dataframe:
DS2_City_df = pd.read_csv('/content/drive/MyDrive/City-Wide.csv')
DS2_City_PL = pd.read_csv('/content/drive/MyDrive/City-Wide Loss.csv')
DS2_City_df.head(10)
# Out:
#   TIME_STAMP        Lon        Lat   GPS Lon   GPS Lat  GPS Speed (km/h)  \
# 0    51:24.5 -87.626228  41.872849       NaN       NaN               NaN
# 1    51:24.5 -87.626228  41.872849       NaN       NaN               NaN
# 2    51:24.6 -87.626228  41.872849       NaN       NaN               NaN
# 3    51:24.6 -87.626228  41.872849 -87.62623  41.87285               0.0
# 4    51:25.5 -87.626221  41.872955       NaN       NaN               NaN
# 5    51:25.5 -87.626221  41.872959       NaN       NaN               NaN
# 6    51:25.6 -87.626221  41.872959 -87.62622  41.87296               3.0
# 7    51:25.6 -87.626221  41.872959       NaN       NaN               NaN
# 8    51:25.6 -87.626221  41.872959       NaN       NaN               NaN
# 9    51:26.3 -87.626221  41.872959       NaN       NaN               NaN
#
#    LTE KPI PCell Serving PCI LTE KPI PCell Serving Band  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                      497.0                     Band 2
# 5                        NaN                        NaN
# 6                        NaN                        NaN
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                      497.0                     Band 2
#
#    LTE KPI PCell Serving EARFCN(DL)  LTE KPI PCell Serving RSRP[dBm]  ...  \
# 0                               NaN                              NaN  ...
# 1                               NaN                              NaN  ...
# 2                               NaN                              NaN  ...
# 3                               NaN                              NaN  ...
# 4                             675.0                           -96.94  ...
# 5                               NaN                              NaN  ...
# 6                               NaN                              NaN  ...
# 7                               NaN                              NaN  ...
# 8                               NaN                              NaN  ...
# 9                             675.0                           -97.44  ...
#
#    PCI Beam Switch Analysis PCell Inter-Beam Switch  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
#
#    UE Beam Switch Analysis PCell UE Beam Switch without Tx Beam Switch  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    UE Beam Switch Analysis PCell UE Beam Switch Delay Time [sec]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    API GPS Info Estimated accuracy  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              0.0
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
#
#   Smart Phone Android System Info Phone Model  \
# 0                                   SM-G998U1
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#    Smart Phone Android System Info Operator  \
# 0                                      AT&T
# 1                                       NaN
# 2                                      AT&T
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                      AT&T
# 8                                      AT&T
# 9                                       NaN
#
#    Smart Phone Android System Info Phone OS Ver  \
# 0                                          11.0
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
#
#    Smart Phone Android System Info Battery Temperature  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                               23.2
# 8                                                NaN
# 9                                                NaN
#
#   5G-NR RRC NSA RRC State Info NSA RRC State 5G KPI PCell RF Pathloss [dB]
# 0                                        NaN                           NaN
# 1                               LTE RRC Idle                           NaN
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# 5                                        NaN                           NaN
# 6                                        NaN                           NaN
# 7                                        NaN                           NaN
# 8                                        NaN                           NaN
# 9                                        NaN                           NaN
#
# [10 rows x 78 columns]

# %%
DS2_City_df['5G KPI PCell RF Pathloss [dB]'] = DS2_City_PL['5G KPI PCell RF Pathloss [dB]']
DS2_City_df = DS2_City_df[DS2_City_df['5G KPI PCell RF Pathloss [dB]'].notna()]
DS2_City_df = DS2_City_df[['5G KPI PCell RF Serving SS-SINR [dB]', 'LTE KPI PCell Serving RSRP[dBm]', 'LTE KPI PCell Serving RSRQ[dB]', '5G KPI PCell RF Serving SS-RSRQ [dB]', '5G KPI PCell RF Best Beam SS-RSRP [dBm]', '5G KPI PCell RF Pathloss [dB]']]
DS2_City_df = DS2_City_df.ffill()
DS2_City_df = DS2_City_df.dropna()

# %%
#Downtown (High Density) Dataframe:
DS2_Downtown_df = pd.read_csv('/content/drive/MyDrive/Downtown.csv')
DS2_Downtown_PL = pd.read_csv('/content/drive/MyDrive/Downtown Loss.csv')
DS2_Downtown_df.head(10)
# Out:
#   TIME_STAMP        Lon        Lat   GPS Lon   GPS Lat  GPS Speed (km/h)  \
# 0    31:23.0 -87.630547  41.878319       NaN       NaN               NaN
# 1    31:23.7 -87.630547  41.878319       NaN       NaN               NaN
# 2    31:23.8 -87.630547  41.878319       NaN       NaN               NaN
# 3    31:23.9 -87.630547  41.878319       NaN       NaN               NaN
# 4    31:24.0 -87.630547  41.878319       NaN       NaN               NaN
# 5    31:24.0 -87.630547  41.878319       NaN       NaN               NaN
# 6    31:24.0 -87.630547  41.878319 -87.63055  41.87832               0.0
# 7    31:25.0 -87.630547  41.878319 -87.63055  41.87832               0.0
# 8    31:26.0 -87.630547  41.878319 -87.63055  41.87832               0.0
# 9    31:27.0 -87.630547  41.878319       NaN       NaN               NaN
#
#    GPS Distance (m) Event HTTP Call Event Event Technology  \
# 0               NaN                   NaN        5G-NR_NSA
# 1               NaN                   NaN              NaN
# 2               NaN                   NaN              NaN
# 3               NaN                  Idle              NaN
# 4               NaN                  Idle              NaN
# 5               NaN                  Idle              NaN
# 6               NaN                  Idle              NaN
# 7               0.0                  Idle              LTE
# 8               0.0                  Idle              LTE
# 9               NaN                  Idle              LTE
#
#          Event LTE Events  ... 5G KPI SCell[7] Layer1 DL BLER [%]  \
# 0                     NaN  ...                                NaN
# 1  RRC Connection Release  ...                                NaN
# 2    Cell Searching Start  ...                                NaN
# 3                     NaN  ...                                NaN
# 4            Cell Camp On  ...                                NaN
# 5            Cell Camp On  ...                                NaN
# 6                     NaN  ...                                NaN
# 7                     NaN  ...                                NaN
# 8                     NaN  ...                                NaN
# 9                     NaN  ...                                NaN
#
#    5G KPI SCell[7] Layer1 DL RB Num (Avg)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
#
#    5G KPI SCell[7] Layer1 PDSCH Throughput [Mbps]  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
#
#    Smart Phone Smart Throughput Mobile Network DL Throughput  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                0.0
# 7                                                0.0
# 8                                                0.0
# 9                                                0.0
#
#    Smart Phone Smart Throughput Mobile Network UL Throughput  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                0.0
# 7                                                0.0
# 8                                                0.0
# 9                                                0.0
#
#   Smart Phone Smart Throughput Mobile Network Rx Byte  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                0.0
# 7                                                0.0
# 8                                                0.0
# 9                                                0.0
#
#    Smart Phone Smart Throughput Mobile Network Tx Byte  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                0.0
# 7                                                0.0
# 8                                                0.0
# 9                                                0.0
#
#   API GPS Info Estimated accuracy  API GPS Info Speed  \
# 0                             0.0                 0.0
# 1                             NaN                 NaN
# 2                             NaN                 NaN
# 3                             NaN                 NaN
# 4                             NaN                 NaN
# 5                             NaN                 NaN
# 6                             0.0                 0.0
# 7                             0.0                 0.0
# 8                             0.0                 0.0
# 9                             0.0                 0.0
#
#    5G KPI PCell RF Pathloss [dB]
# 0                          91.11
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
#
# [10 rows x 306 columns]

# %%
DS2_Downtown_df['5G KPI PCell RF Pathloss [dB]'] = DS2_Downtown_PL['5G KPI PCell RF Pathloss [dB]']
DS2_Downtown_df = DS2_Downtown_df[DS2_Downtown_df['5G KPI PCell RF Pathloss [dB]'].notna()]
DS2_Downtown_df = DS2_Downtown_df[['5G KPI PCell RF Serving SS-SINR [dB]', 'LTE KPI PCell Serving RSRP[dBm]', 'LTE KPI PCell Serving RSRQ[dB]', '5G KPI PCell RF Serving SS-RSRQ [dB]', '5G KPI PCell RF Best Beam SS-RSRP [dBm]', '5G KPI PCell RF Pathloss [dB]']]
DS2_Downtown_df = DS2_Downtown_df.ffill()
DS2_Downtown_df = DS2_Downtown_df.dropna()

# %%
import pickle as pkl

# %%
file = open("DS1_Rural.pkl", 'wb')
pkl.dump(DS1_Rural_df, file)
file.close()

file = open("DS1_Urban.pkl", 'wb')
pkl.dump(DS1_Urban_df, file)
file.close()

file = open("DS1_Suburban.pkl", 'wb')
pkl.dump(DS1_Suburban_df, file)
file.close()

file = open("DS2_Baseball.pkl", 'wb')
pkl.dump(DS2_Baseball_df, file)
file.close()

file = open("DS2_City-Wide.pkl", 'wb')
pkl.dump(DS2_City_df, file)
file.close()

file = open("DS2_Downtown.pkl", 'wb')
pkl.dump(DS2_Downtown_df, file)
file.close()

# %%
# %cd /content
# Out:
# /content

# %%
# !zip -r PickleFiles.zip PickleFiles/
# Out:
#   adding: PickleFiles/ (stored 0%)
#   adding: PickleFiles/DS1_Rural.pkl (deflated 76%)
#   adding: PickleFiles/DS2_Downtown.pkl (deflated 82%)
#   adding: PickleFiles/DS2_Baseball.pkl (deflated 93%)
#   adding: PickleFiles/DS1_Suburban.pkl (deflated 70%)
#   adding: PickleFiles/DS2_City-Wide.pkl (deflated 94%)
#   adding: PickleFiles/DS1_Urban.pkl (deflated 71%)

# %%
from google.colab import files
files.download('PickleFiles.zip')
